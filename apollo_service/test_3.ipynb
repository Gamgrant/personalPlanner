# %%
import os
import json
import requests

BASE_URL = "https://api.apollo.io/api/v1"

# Prefer env var; fallback only for local testing (not recommended for prod)
APOLLO_API_KEY = os.getenv("APOLLO_API_KEY", "ha52Fyh29mmmdhZ7gRbSmA")


def get_headers() -> dict:
    return {
        "accept": "application/json",
        "content-type": "application/json",
        "cache-control": "no-cache",
        "x-api-key": APOLLO_API_KEY,
    }


def extract_email_and_phone(data: dict) -> tuple[str | None, str | None]:
    """
    Best-effort extraction of:
      - work email
      - sanitized phone

    Checks:
      - person.email
      - person.email_addresses / contact_emails
      - contact.email
      - person.phone_numbers[*].sanitized_number
      - person.sanitized_phone / phone_number / phone
      - contact.sanitized_phone
      - contact.phone_numbers[*].sanitized_number
      - organization.primary_phone.sanitized_number
      - organization.sanitized_phone
    """
    person = data.get("person") or {}
    contact = data.get("contact") or person.get("contact") or {}
    org = person.get("organization") or data.get("organization") or {}

    # -------- Email --------
    email = None

    # 1) Direct
    if isinstance(person.get("email"), str):
        email = person["email"].strip() or None

    # 2) From email_addresses / contact_emails
    if not email:
        emails = person.get("email_addresses") or person.get("contact_emails") or []
        if isinstance(emails, list):
            for e in emails:
                if not isinstance(e, dict):
                    continue
                addr = (e.get("email") or "").strip()
                etype = (e.get("type") or "").lower()
                if addr:
                    if etype == "work":
                        email = addr
                        break
                    if not email:
                        email = addr

    # 3) contact.email
    if not email and isinstance(contact.get("email"), str):
        email = contact["email"].strip() or None

    # -------- Phone (sanitized) --------
    phone = None

    # 1) person.phone_numbers[*].sanitized_number
    phones = person.get("phone_numbers") or []
    if isinstance(phones, list):
        for p in phones:
            if not isinstance(p, dict):
                continue
            sn = (p.get("sanitized_number") or p.get("sanitized_phone") or "").strip()
            rn = (p.get("raw_number") or "").strip()
            ptype = (p.get("type") or "").lower()

            if sn:
                # Prefer work-ish types, but accept any if nothing else
                if ptype in ("work", "work_direct", "direct", "mobile", "other"):
                    phone = sn
                    break
                if not phone:
                    phone = sn
            elif rn and not phone:
                phone = rn

    # 2) person.sanitized_phone / phone_number / phone
    if not phone:
        for key in ("sanitized_phone", "phone_number", "phone"):
            val = person.get(key)
            if isinstance(val, str) and val.strip():
                phone = val.strip()
                break

    # 3) contact.sanitized_phone
    if not phone:
        val = contact.get("sanitized_phone")
        if isinstance(val, str) and val.strip():
            phone = val.strip()

    # 4) contact.phone_numbers[*].sanitized_number
    if not phone:
        cphones = contact.get("phone_numbers") or []
        if isinstance(cphones, list):
            for p in cphones:
                if not isinstance(p, dict):
                    continue
                sn = (p.get("sanitized_number") or p.get("sanitized_phone") or "").strip()
                rn = (p.get("raw_number") or "").strip()
                if sn:
                    phone = sn
                    break
                if rn and not phone:
                    phone = rn

    # 5) organization.primary_phone.sanitized_number
    if not phone:
        primary_phone = (org.get("primary_phone") or {})
        val = primary_phone.get("sanitized_number") or primary_phone.get("number")
        if isinstance(val, str) and val.strip():
            phone = val.strip()

    # 6) organization.sanitized_phone
    if not phone:
        val = org.get("sanitized_phone")
        if isinstance(val, str) and val.strip():
            phone = val.strip()

    return email, phone


def match_with_phone_example() -> None:
    webhook_url = (
        "https://kaylyn-pseudomythical-jeffrey.ngrok-free.dev"
        "/apollo-webhook?token=super-secret-token"
    )

    payload = {
        "first_name": "Marisa",
        "last_name": "Rhazzal",
        "domain": "asana.com",
        "reveal_personal_emails": False,
        "reveal_phone_number": True,
        "webhook_url": webhook_url,
    }

    print(">>> Calling Apollo /people/match")
    print(f"Request URL: {BASE_URL}/people/match")
    print("Request Payload:")
    print(json.dumps(payload, indent=2))

    resp = requests.post(f"{BASE_URL}/people/match", headers=get_headers(), json=payload)

    print("\n>>> Response")
    print(f"HTTP {resp.status_code}")

    try:
        data = resp.json()
        return
        print("Full JSON:")
        print(json.dumps(data, indent=2))

        email, phone = extract_email_and_phone(data)

        print("\n--- Extracted Values ---")
        print(f"Email: {email or '(none found)'}")
        print(f"Sanitized phone: {phone or '(none found)'}")

    except ValueError:
        # Not JSON
        print("Raw response text:")
        print(resp.text)
    



dick = match_with_phone_example()
# Out:
# >>> Calling Apollo /people/match
# Request URL: https://api.apollo.io/api/v1/people/match
# Request Payload:
# {
#   "first_name": "Lindsay",
#   "last_name": "Brown",
#   "domain": "asana.com",
#   "reveal_personal_emails": false,
#   "reveal_phone_number": true,
#   "webhook_url": "https://kaylyn-pseudomythical-jeffrey.ngrok-free.dev/apollo-webhook?token=super-secret-token"
# }
#
# >>> Response
# HTTP 200

# %%
data["person"]
# Out:
# {'id': '69117cc2d6998a001de7ecb9',
#  'first_name': 'Lindsay',
#  'last_name': 'Brown',
#  'name': 'Lindsay Brown',
#  'linkedin_url': None,
#  'title': None,
#  'email_status': None,
#  'photo_url': None,
#  'twitter_url': None,
#  'github_url': None,
#  'facebook_url': None,
#  'extrapolated_email_confidence': None,
#  'headline': None,
#  'email': None,
#  'organization_id': '54a121bb69702d8ed411cb02',
#  'employment_history': [{'_id': '69117cc2d6998a001de7ecba',
#    'created_at': None,
#    'current': True,
#    'degree': None,
#    'description': None,
#    'emails': None,
#    'end_date': None,
#    'grade_level': None,
#    'kind': None,
#    'major': None,
#    'organization_id': '54a121bb69702d8ed411cb02',
#    'organization_name': None,
#    'raw_address': None,
#    'start_date': None,
#    'title': None,
#    'updated_at': None,
#    'id': '69117cc2d6998a001de7ecba',
#    'key': '69117cc2d6998a001de7ecba'}],
#  'organization': {'id': '54a121bb69702d8ed411cb02',
#   'name': 'Asana',
#   'website_url': 'http://www.asana.com',
#   'blog_url': None,
#   'angellist_url': None,
#   'linkedin_url': 'http://www.linkedin.com/company/asana',
#   'twitter_url': 'https://twitter.com/asana',
#   'facebook_url': 'https://www.facebook.com/asana',
#   'primary_phone': {'number': '+1 415-525-3888',
#    'source': 'Owler',
#    'sanitized_number': '+14155253888'},
#   'languages': ['English'],
#   'alexa_ranking': 286,
#   'phone': '+1 415-525-3888',
#   'linkedin_uid': '807257',
#   'founded_year': 2008,
#   'publicly_traded_symbol': 'ASAN',
#   'publicly_traded_exchange': 'nasdaq',
#   'logo_url': 'https://zenprospect-production.s3.amazonaws.com/uploads/pictures/690c80045812c2000192fd8a/picture',
#   'crunchbase_url': None,
#   'primary_domain': 'asana.com',
#   'sic_codes': ['7374'],
#   'naics_codes': ['54151'],
#   'sanitized_phone': '+14155253888',
#   'market_cap': '3.1B',
#   'industry': 'information technology & services',
#   'estimated_num_employees': 1900,
#   'keywords': ['work management',
#    'productivity',
#    'project management',
#    'organization',
#    'collaboration',
#    'digital transformation',
#    'software',
#    'productivity software',
#    'task management',
#    'information technology',
#    'internet',
#    'business productivity',
#    'enterprise software',
#    'computer software: prepackaged software',
#    'technology',
#    'software development',
#    'enterprise collaboration',
#    'dashboard reporting',
#    'goal setting',
#    'project tracking',
#    'enterprise solutions',
#    'automation workflows',
#    'services',
#    'cross-functional teams',
#    'integrations',
#    'ai-powered features',
#    'team productivity',
#    'operational efficiency',
#    'goal management',
#    'real-time updates',
#    'mobile apps',
#    'file sharing',
#    'team alignment',
#    'project portfolio management',
#    'education',
#    'ai integration',
#    'non-profit',
#    'collaboration tools',
#    'portfolio management',
#    'task assignment',
#    'professional services',
#    'workflow builder',
#    'team collaboration',
#    'ai-driven insights',
#    'cloud-based platform',
#    'computer software',
#    'team workload management',
#    'marketing',
#    'real-time monitoring',
#    'manufacturing',
#    'healthcare',
#    'performance metrics',
#    'computer systems design and related services',
#    'customizable views',
#    'workflow automation',
#    'b2b',
#    'collaborative work platform',
#    'task tracking',
#    'task dependencies',
#    'automated status updates',
#    'financial services',
#    'goal tracking software',
#    'user-friendly interface',
#    'goal tracking',
#    'resource management',
#    'status updates',
#    'reporting dashboards',
#    'campaign management',
#    'creative production',
#    'okr software',
#    'custom templates',
#    'workload management',
#    'real-time insights',
#    'cross-functional planning',
#    'integration capabilities',
#    'admin and security',
#    'process standardization',
#    'stakeholder communication',
#    'creative approval workflows',
#    'template library',
#    'agile methodologies',
#    'gantt charts',
#    'kanban boards',
#    'collaborative work',
#    'enterprise-grade security',
#    'project intake forms',
#    'resource allocation',
#    'capacity planning',
#    'team workflows',
#    'business continuity plans',
#    'project milestones',
#    'customizable dashboards',
#    'visibility into workloads',
#    'data-driven decision making',
#    'automated reporting',
#    'customer success',
#    'implementation support',
#    'project timelines',
#    'milestone tracking',
#    'employee onboarding',
#    'process mapping',
#    'workload balancing',
#    'team productivity tools',
#    'saas',
#    'information technology & services',
#    'enterprises',
#    'nonprofit organization management',
#    'professional training & coaching',
#    'mechanical or industrial engineering',
#    'health care',
#    'health, wellness & fitness',
#    'hospital & health care'],
#   'organization_revenue_printed': '738.7M',
#   'organization_revenue': 738695000.0,
#   'industries': ['information technology & services'],
#   'secondary_industries': [],
#   'snippets_loaded': True,
#   'industry_tag_id': '5567cd4773696439b10b0000',
#   'industry_tag_hash': {'information technology & services': '5567cd4773696439b10b0000'},
#   'retail_location_count': 0,
#   'raw_address': '633 Folsom Street, Suite 100, San Francisco, California 94107, US',
#   'street_address': '633 Folsom St',
#   'city': 'San Francisco',
#   'state': 'California',
#   'postal_code': '94107-3600',
#   'country': 'United States',
#   'owned_by_organization_id': None,
#   'short_description': "Asana, Inc. is a technology company founded in 2008 by Dustin Moskovitz and Justin Rosenstein. Headquartered in San Francisco, it has additional offices in Tokyo, Vancouver, Warsaw, and Singapore. Asana develops a project and work management platform that helps teams coordinate, track, and manage their work efficiently.\n\nThe core product, also named Asana, is a workflow and project management tool that allows organizations to break down projects into smaller tasks, assign responsibilities, and set deadlines. It aims to minimize time spent on meetings and searching for information, enabling users to focus on their core work. Asana is available as a web application and through native apps for iOS, Android, and desktop, supporting collaboration across devices. The platform integrates with tools like Gmail and is available in multiple languages.\n\nAsana serves over 100,000 paying organizations worldwide, including notable customers such as eBay, Uber, and IBM. The company's name reflects its mission to bring ease and focus to work processes.",
#   'suborganizations': [],
#   'num_suborganizations': 0,
#   'annual_revenue_printed': '738.7M',
#   'annual_revenue': 738695000.0,
#   'technology_names': ['AI',
#    'Amazon AWS',
#    'Amazon SES',
#    'Atlassian Cloud',
#    'Citrix',
#    'Gmail',
#    'Google Apps',
#    'Greenhouse.io',
#    'Marketo',
#    'Netlify',
#    'OneTrust',
#    'Route 53',
#    'Stripe',
#    'The Trade Desk',
#    'WP Engine'],
#   'current_technologies': [{'uid': 'ai', 'name': 'AI', 'category': 'Other'},
#    {'uid': 'amazon_aws', 'name': 'Amazon AWS', 'category': 'Hosting'},
#    {'uid': 'amazon_ses', 'name': 'Amazon SES', 'category': 'Email Delivery'},
#    {'uid': 'atlassian_cloud', 'name': 'Atlassian Cloud', 'category': 'CMS'},
#    {'uid': 'citrix',
#     'name': 'Citrix',
#     'category': 'Frameworks and Programming Languages'},
#    {'uid': 'gmail', 'name': 'Gmail', 'category': 'Email Providers'},
#    {'uid': 'google_apps', 'name': 'Google Apps', 'category': 'Other'},
#    {'uid': 'greenhouse_io',
#     'name': 'Greenhouse.io',
#     'category': 'Recruitment'},
#    {'uid': 'marketo', 'name': 'Marketo', 'category': 'Marketing Automation'},
#    {'uid': 'netlify', 'name': 'Netlify', 'category': 'CMS'},
#    {'uid': 'onetrust', 'name': 'OneTrust', 'category': 'Widgets'},
#    {'uid': 'route_53', 'name': 'Route 53', 'category': 'Domain Name Services'},
#    {'uid': 'stripe', 'name': 'Stripe', 'category': 'Payments'},
#    {'uid': 'the_trade_desk',
#     'name': 'The Trade Desk',
#     'category': 'Demand Side Platforms'},
#    {'uid': 'wp_engine', 'name': 'WP Engine', 'category': 'CMS'}],
#   'org_chart_root_people_ids': ['66f2afad97d1f600015b63e3'],
#   'org_chart_sector': 'OrgChart::SectorHierarchy::Rules::IT',
#   'org_chart_removed': False,
#   'org_chart_show_department_filter': True,
#   'organization_headcount_six_month_growth': None,
#   'organization_headcount_twelve_month_growth': None,
#   'organization_headcount_twenty_four_month_growth': None},
#  'intent_strength': None,
#  'show_intent': False,
#  'email_domain_catchall': False,
#  'revealed_for_current_team': True,
#  'departments': [],
#  'subdepartments': [],
#  'functions': [],
#  'seniority': None}
